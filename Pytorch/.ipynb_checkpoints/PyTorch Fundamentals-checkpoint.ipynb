# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cpu

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
import numpy as np
array = np.array([1, 2, 3, 4])
print(array * 2)  # Element-wise operation
# Out:
# [2 4 6 8]

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.title('Sample Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
